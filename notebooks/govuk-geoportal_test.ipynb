# %% [markdown]
# # GOVUK GEOPORTAL Tests

# %%
import sys

# %%
sys.path.append('../property-fundamentals')
from govuk_ws.geoportal.postcode_to_ward import PostcodeMapping

# %%
postcode_mapping = PostcodeMapping()

# %%
postcode_mapping.get_postcodes()
# Out:
# ['AL1 1AG',
#  'AL1 1AJ',
#  'AL1 1AR',
#  'AL1 1AS',
#  'AL1 1BH',
#  'AL1 1BX',
#  'AL1 1BY',
#  'AL1 1BZ',
#  'AL1 1DG',
#  'AL1 1DH',
#  'AL1 1DQ',
#  'AL1 1DS',
#  'AL1 1DU',
#  'AL1 1DW',
#  'AL1 1DX',
#  'AL1 1DZ',
#  'AL1 1EA',
#  'AL1 1EB',
#  'AL1 1EE',
#  'AL1 1ER',
#  'AL1 1EU',
#  'AL1 1EZ',
#  'AL1 1HA',
#  'AL1 1HB',
#  'AL1 1HF',
#  'AL1 1HH',
#  'AL1 1HL',
#  'AL1 1HN',
#  'AL1 1HP',
#  'AL1 1HQ',
#  'AL1 1HR',
#  'AL1 1HU',
#  'AL1 1HW',
#  'AL1 1HY',
#  'AL1 1JA',
#  'AL1 1JE',
#  'AL1 1JG',
#  'AL1 1JH',
#  'AL1 1JJ',
#  'AL1 1JL',
#  'AL1 1JN',
#  'AL1 1JP',
#  'AL1 1JQ',
#  'AL1 1JR',
#  'AL1 1JS',
#  'AL1 1JT',
#  'AL1 1JU',
#  'AL1 1JW',
#  'AL1 1LA',
#  'AL1 1LB',
#  'AL1 1LE',
#  'AL1 1LJ',
#  'AL1 1LS',
#  'AL1 1LT',
#  'AL1 1LZ',
#  'AL1 1NB',
#  'AL1 1ND',
#  'AL1 1NE',
#  'AL1 1NF',
#  'AL1 1NG',
#  'AL1 1NH',
#  'AL1 1NJ',
#  'AL1 1NL',
#  'AL1 1NN',
#  'AL1 1NQ',
#  'AL1 1NU',
#  'AL1 1NX',
#  'AL1 1PA',
#  'AL1 1PB',
#  'AL1 1PD',
#  'AL1 1PF',
# ...

# %%
postcode_mapping.get_ward_from_postcode('OX29 8HL')
# Out:
# 'Freeland and Hanborough'
