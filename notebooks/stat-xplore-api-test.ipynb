# %% [markdown]
# # Google API Tests

# %%
import sys

# %%
import requests
import json

# %%
r = requests.get('https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema', headers = {'apikey':''})
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "id": "str:folder:root",
#   "label": "Stat-Xplore",
#   "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:folder:root",
#   "type": "FOLDER",
#   "children": [
#     {
#       "id": "str:folder:facc",
#       "label": "Alternative Claimant Count",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:folder:facc",
#       "type": "FOLDER"
#     },
#     {
#       "id": "str:folder:faa",
#       "label": "Attendance Allowance",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:folder:faa",
#       "type": "FOLDER"
#     },
#     {
#       "id": "str:folder:fbc",
#       "label": "Benefit Cap",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:folder:fbc",
#       "type": "FOLDER"
#     },
#     {
#       "id": "str:folder:fbencom",
#       "label": "Benefit Combinations",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:folder:fbencom",
# ...

# %%
r = requests.get('https://stat-xplore.dwp.gov.uk/webapi/rest/v1/info', headers = {'apikey':''})
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "languages": []
# }

# %%
r = requests.get('https://stat-xplore.dwp.gov.uk/webapi/rest/v1/rate_limit', headers = {'apikey':''})
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "remaining": 9988,
#   "limit": 10000,
#   "reset": 1660941551423
# }

# %%
r = requests.get('https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:valueset:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA', headers = {'apikey':''})
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "id": "str:valueset:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA",
#   "label": "Ward",
#   "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:valueset:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA",
#   "type": "VALUESET",
#   "children": [
#     {
#       "id": "str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05000455",
#       "label": "Abbey",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05000455",
#       "type": "VALUE"
#     },
#     {
#       "id": "str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05001767",
#       "label": "Abbey",
#       "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05001767",
#       "type": "VALUE"
#     },
# ...

# %%
r = requests.get('https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05002196', headers = {'apikey':''})
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "id": "str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05002196",
#   "label": "Challney",
#   "location": "https://stat-xplore.dwp.gov.uk/webapi/rest/v1/schema/str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05002196",
#   "type": "VALUE",
#   "children": []
# }

# %%
ward = 'E05002455'

data = {
    "database" : "str:database:UC_Households",
    "measures" : ["str:count:UC_Households:V_F_UC_HOUSEHOLDS"],
    "recodes": {
      "str:field:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE": {
        "map": [
          [
            "str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:" + ward
          ],
        ],
        "total": True
      },
      "str:field:UC_Households:F_UC_HH_DATE:DATE_NAME": {
        "map": [
          [
            "str:value:UC_Households:F_UC_HH_DATE:DATE_NAME:C_UC_HH_DATE:202205"
          ]
        ],
        "total": False
      }
    },
    "dimensions": [
      [
        "str:field:UC_Households:F_UC_HH_DATE:DATE_NAME"
      ],
      [
        "str:field:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE"
      ]
    ]
}

# %%
url = 'https://stat-xplore.dwp.gov.uk/webapi/rest/v1/table'
headers = {'Content-type': 'application/json','apikey':''}
r = requests.post(url, data=json.dumps(data), headers=headers)
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "query": {
#     "database": "str:database:UC_Households",
#     "measures": [
#       "str:count:UC_Households:V_F_UC_HOUSEHOLDS"
#     ],
#     "recodes": {
#       "str:field:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE": {
#         "map": [
#           [
#             "str:value:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05002455"
#           ]
#         ],
#         "total": true
#       },
#       "str:field:UC_Households:F_UC_HH_DATE:DATE_NAME": {
#         "map": [
#           [
#             "str:value:UC_Households:F_UC_HH_DATE:DATE_NAME:C_UC_HH_DATE:202205"
#           ]
#         ],
#         "total": false
#       }
#     },
#     "dimensions": [
#       [
#         "str:field:UC_Households:F_UC_HH_DATE:DATE_NAME"
#       ],
#       [
#         "str:field:UC_Households:V_F_UC_HOUSEHOLDS:WARD_CODE"
#       ]
#     ]
#   },
#   "database": {
#     "id": "UC_Households",
#     "uri": "str:database:UC_Households",
# ...

# %%
print(json_object["measures"][0]["label"])
print(json_object["fields"][0]["items"][0]["labels"][0])
print(json_object["fields"][1]["items"][0]["labels"][0])
print(json_object["cubes"]["str:count:UC_Households:V_F_UC_HOUSEHOLDS"]['values'][0][0])
# Out:
# Households on Universal Credit
# May 2022
# Bargate
# 2245.0

# %%
r.status_code
# Out:
# 422

# %%
print(r)
# Out:
# <Response [422]>

# %%
ward2 = 'E05002455'

data2= {
    "database" : "str:database:hb_new",
    "measures" : ["str:count:hb_new:V_F_HB_NEW"],
    "recodes": {
      "str:field:hb_new:V_F_HB_NEW:WARD_CODE": {
        "map": [
          [
            "str:value:hb_new:V_F_HB_NEW:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:" + ward2
          ],
        ],
        "total": True
      },
      "str:field:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME": {
        "map": [
          [
            "str:value:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME:C_HB_NEW_DATE:202205"
          ]
        ],
        "total": False
      }
    },
    "dimensions": [
      [
        "str:field:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME"
      ],
      [
        "str:field:hb_new:V_F_HB_NEW:WARD_CODE"
      ]
    ]
}

# %%
url = 'https://stat-xplore.dwp.gov.uk/webapi/rest/v1/table'
headers = {'Content-type': 'application/json','apikey':''}
r2 = requests.post(url, data=json.dumps(data2), headers=headers)
json_object2 = json.loads(r2.content)
json_formatted_str2 = json.dumps(json_object2, indent=2)
print(json_formatted_str2)
# Out:
# {
#   "query": {
#     "database": "str:database:hb_new",
#     "measures": [
#       "str:count:hb_new:V_F_HB_NEW"
#     ],
#     "recodes": {
#       "str:field:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME": {
#         "map": [
#           [
#             "str:value:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME:C_HB_NEW_DATE:202205"
#           ]
#         ],
#         "total": false
#       },
#       "str:field:hb_new:V_F_HB_NEW:WARD_CODE": {
#         "map": [
#           [
#             "str:value:hb_new:V_F_HB_NEW:WARD_CODE:V_C_MASTERGEOG11_WARD_TO_LA:E05002455"
#           ]
#         ],
#         "total": true
#       }
#     },
#     "dimensions": [
#       [
#         "str:field:hb_new:F_HB_NEW_DATE:NEW_DATE_NAME"
#       ],
#       [
#         "str:field:hb_new:V_F_HB_NEW:WARD_CODE"
#       ]
#     ]
#   },
#   "database": {
#     "id": "hb_new",
#     "uri": "str:database:hb_new",
#     "label": "Housing Benefit - Data from April 2018",
#     "annotationKeys": [
#       "XXI"
#     ]
# ...

# %%
print(json_object2["measures"][0]["label"])
print(json_object2["fields"][0]["items"][0]["labels"][0])
print(json_object2["fields"][1]["items"][0]["labels"][0])
print(json_object2["cubes"]["str:count:hb_new:V_F_HB_NEW"]['values'][0][0])
# Out:
# Housing Benefit Claimants
# 202205 (May-22)
# Bargate
# 962.0
