# %% [markdown]
# # Police API Tests

# %%
import sys

# %%
sys.path.append('../property-fundamentals')
from police_api.api import API

# %%
police_api = API()

# %%
results = police_api.get_street_level_crimes(52.629729, -1.131592, 10000, "2020-01")

# %%
len(results)
# Out:
# 5053

# %%
results
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.579450',
#    'street': {'id': 879968, 'name': 'On or near Penzance Avenue'},
#    'longitude': '-1.108055'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 80450651,
#   'location_subtype': '',
#   'month': '2020-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.635448',
#    'street': {'id': 883109, 'name': 'On or near Nottingham Road'},
#    'longitude': '-1.102040'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 80447035,
#   'location_subtype': '',
#   'month': '2020-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '52.664366',
#    'street': {'id': 885291, 'name': 'On or near Collett Road'},
#    'longitude': '-1.151736'},
#   'context': '',
#   'outcome_status': None,
# ...

# %%
for r in results:
    print(r['category'])
# Out:
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# anti-social-behaviour
# ...
