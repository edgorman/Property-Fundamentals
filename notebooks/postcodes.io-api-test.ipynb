# %% [markdown]
# # Police API Tests

# %%
import sys

# %%
import requests
import json

# %%
sys.path.append('../property-fundamentals')
from postcodes_api.postcode_api import API

# %%
postcodes_api = API()

# %%
headers = {'radius': '2000'}
r = requests.get('https://api.postcodes.io/postcodes?lon=-1.3957679&lat=50.9037234', headers=headers)
json_object = json.loads(r.content)
json_formatted_str = json.dumps(json_object, indent=2)
print(json_formatted_str)
# Out:
# {
#   "status": 200,
#   "result": [
#     {
#       "postcode": "SO14 1AR",
#       "quality": 1,
#       "eastings": 442629,
#       "northings": 111726,
#       "country": "England",
#       "nhs_ha": "South Central",
#       "longitude": -1.39513,
#       "latitude": 50.903441,
#       "european_electoral_region": "South East",
#       "primary_care_trust": "Southampton City",
#       "region": "South East",
#       "lsoa": "Southampton 029E",
#       "msoa": "Southampton 029",
#       "incode": "1AR",
#       "outcode": "SO14",
#       "parliamentary_constituency": "Southampton, Itchen",
#       "admin_district": "Southampton",
#       "parish": "Southampton, unparished area",
#       "admin_county": null,
#       "admin_ward": "Bargate",
#       "ced": null,
#       "ccg": "NHS Hampshire, Southampton and Isle of Wight",
#       "nuts": "Southampton",
#       "codes": {
#         "admin_district": "E06000045",
#         "admin_county": "E99999999",
# ...

# %%
print(json_object["result"][0]["postcode"])
# Out:
# SO14 1AR

# %%
further_education_postcode = postcodes_api.get_postcode('-1.3957679','50.9037234')
print(further_education_postcode)
# Out:
# SO14 1AR
